# %%
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\Dell\Dropbox\PC\Desktop\Placement.csv")

# %%
df.head()
# Out:
#    1  cgpa  package
# 0  2  6.89     3.26
# 1  3  5.12     1.98
# 2  4  7.82     3.25
# 3  5  7.42     3.67
# 4  6  6.94     3.57

# %%
df.isnull().sum()
# Out:
# 1          0
# cgpa       0
# package    0
# dtype: int64
